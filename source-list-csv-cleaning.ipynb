# %%
# Import the csv I created after tabulating the PDF with Camelot
# Telling pandas where the header is
import pandas as pd
df = pd.read_csv("csv/MI-source-list-converted.csv", header=2)
df
# Out:
#                                      Source ID\nCompany  \
# 0          N8277\nTUSCOLA ENERGY INC - RUMBLE SHARP CTB
# 1     N8274\nTUSCOLA ENERGY INC-BOYCE JR TRUSTEE 1&S...
# 2                                    U04060035\nUNKNOWN
# 3                     N7824\nRIVERSIDE - FOREST HOME 12
# 4                                    U15060046\nUNKNOWN
# ...                                                 ...
# 5972                                              P1069
# 5973                                              P0067
# 5974                                              N1973
# 5975           U831506751 GALLAGHER ASPHALT CORPORATION
# 5976                                          U82060106
#
#                                     Address                         City  \
# 0                  SE SW SW SEC 19 T14N R8E                        AKRON
# 1                  SW SW SW SEC 24 T14N R7E                        AKRON
# 2                             ALPENA COUNTY                       ALPENA
# 3             SW 1/4 NE 1/4 SEC 12 T30N R8W                     BELLAIRE
# 4                         CHARLEVOIX COUNTY                   CHARLEVOIX
# ...                                     ...                          ...
# 5972                 ALTA EQUIPMENT COMPANY            1035 CALCITE ROAD
# 5973                          LAURIE HAMMAR     15524 NORTH ROCK 38TH RD
# 5974                   ABHE & SOVBODA, INC.  BLUE WATER BRIDGE & GRATIOT
# 5975                                    NaN    18100 SOUTH INDIAN AVENUE
# 5976  WAYNE COUNTY GENERAL COMPLAINT SOURCE                          NaN
#
#      ZIP Code County           Unnamed: 4 Unnamed: 5 Other* ROP  PTI  \
# 0                NaN              TUSCOLA       View        NaN  NaN
# 1                NaN              TUSCOLA       View        NaN  NaN
# 2                NaN               ALPENA       View        NaN  NaN
# 3                NaN               ANTRIM       View        NaN  NaN
# 4                NaN           CHARLEVOIX       View        NaN  NaN
# ...              ...                  ...        ...        ...  ...
# 5972     ROGERS CITY  49977\nPRESQUE ISLE        NaN       View  NaN
# 5973            ROCK         49980\nDELTA       View       View  NaN
# 5974      PORT HURON   55372\nSAINT CLAIR       View        NaN  NaN
# 5975        THORNTON       60476\nWEXFORD       View        NaN  NaN
# 5976             NaN            NA\nWAYNE       View        NaN  NaN
#
#      Unnamed: 8
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 5972        NaN
# 5973        NaN
# 5974        NaN
# 5975        NaN
# 5976        NaN
#
# [5977 rows x 9 columns]

# %%
# Filtering out NA Values in the Source Column
# Records without a source ID column are blank rows
df = df[df['Source ID\nCompany'].notna() == True]
df.shape
# Out:
# (5907, 9)

# %%
# 1. ------------- SOURCE ID: CLEAN -------------
# Getting out the source ID
# Making sure everything is divided by an ""\n"
df['Source ID\nCompany'] = df['Source ID\nCompany'].str.replace(" ","\n")
# Splitting on "\n", to get a list of strings.
# Extracting the first string, which is the source ID
df['source_id'] = df['Source ID\nCompany'].str.split("\n").str[0]

# %%
# 2. ------------- CITY: CLEAN -------------
# Getting the cities & source ID's so I can merge on source_id
# For some reason, Camelot read the first page of the pdf differently than the other 70 pages
# And mixed up the columns. That shift happened at record 83

# Get the first 82 rows cities
cities1 = []
for index, row in df.iterrows():
    data = {}
    if index < 83:
        data['id'] = row['source_id']
        data['city'] = row['City']
        cities1.append(data)
len(cities1)


# Get the rest of the cities
cities2 = []
for index, row in df.iterrows():
    data = {}
    if index >= 83:
        data['id'] = row['source_id']
        data['city'] = row['ZIP Code County']
        cities2.append(data)
# Making sure I captured each of the 5907 records
total = len(cities1) + len(cities2)
total
# Out:
# 5907

# %%
cities1
# Out:
# [{'id': 'N8277', 'city': 'AKRON'},
#  {'id': 'N8274', 'city': 'AKRON'},
#  {'id': 'U04060035', 'city': 'ALPENA'},
#  {'id': 'N7824', 'city': 'BELLAIRE'},
#  {'id': 'U15060046', 'city': 'CHARLEVOIX'},
#  {'id': 'N7833', 'city': 'CHARLTON TWP'},
#  {'id': 'P0195', 'city': 'CHESTER TWP'},
#  {'id': 'N7813', 'city': 'CHESTER TWP'},
#  {'id': 'N0317', 'city': 'DETROIT'},
#  {'id': 'N8199', 'city': 'DETROIT'},
#  {'id': 'N7828', 'city': 'DOVER TWP'},
#  {'id': 'N7832', 'city': 'DOVER TWP'},
#  {'id': 'N7476', 'city': 'HILLSDALE'},
#  {'id': 'N8165', 'city': 'IMLAY CITY'},
#  {'id': 'U341414092', 'city': 'IONIA'},
#  {'id': 'U36120455', 'city': 'IRON'},
#  {'id': 'B8878', 'city': 'KALAMAZOO'},
#  {'id': 'A2110', 'city': 'KALAMAZOO'},
#  {'id': 'N8227', 'city': 'LIVONIA'},
#  {'id': 'U561505076', 'city': 'MIDLAND'},
#  {'id': 'U60060087', 'city': 'MONTMORENCY'},
#  {'id': 'B5766', 'city': 'NOVI'},
#  {'id': 'U69060095', 'city': 'OTSEGO'},
#  {'id': 'N7834', 'city': 'OTSEGO LAKE'},
#  {'id': 'N3508', 'city': 'OTTER LAKE'},
#  {'id': 'A2098', 'city': 'PARCHMENT'},
#  {'id': 'B4721', 'city': 'PLYMOUTH'},
#  {'id': 'N4961', 'city': 'ROMULUS'},
#  {'id': 'A8266', 'city': 'ROMULUS'},
#  {'id': 'N8190', 'city': 'ROSEBUSH'},
#  {'id': 'P0228', 'city': 'SAINT HELEN'},
#  {'id': 'B7514', 'city': 'SCHOOLCRAFT'},
#  {'id': 'U632100200', 'city': 'TROY'},
#  {'id': 'M4092', 'city': 'DETROIT'},
#  {'id': 'N2689', 'city': 'ERIE'},
#  {'id': 'N8048', 'city': 'COMMERCE TWP'},
#  {'id': 'N8096', 'city': 'FLINT'},
#  {'id': 'A6260', 'city': 'ALGONAC'},
#  {'id': 'N8094', 'city': 'ALGONAC'},
#  {'id': 'N6769', 'city': 'ALGONAC'},
#  {'id': 'P1024', 'city': 'BYRON CENTER'},
#  {'id': 'U741802378', 'city': 'CLAY TOWNSHIP'},
#  {'id': 'P1089', 'city': 'CONCORD'},
#  {'id': 'P1015', 'city': 'CRYSTAL FALLS'},
#  {'id': 'P1030', 'city': 'DETROIT'},
#  {'id': 'P1147', 'city': 'DETROIT'},
#  {'id': 'P1001', 'city': 'HOLLY'},
#  {'id': 'P1029', 'city': 'KALAMAZOO'},
#  {'id': 'P1090', 'city': 'KENTWOOD'},
#  {'id': 'P0998', 'city': 'MILLINGTON'},
#  {'id': 'P1083', 'city': 'NAUBINWAY'},
#  {'id': 'P1091', 'city': 'NEW HUDSON'},
#  {'id': 'P1112', 'city': 'ORION TWP'},
#  {'id': 'P1000', 'city': 'REESE'},
#  {'id': 'P1016', 'city': 'S ROCKWOOD'},
#  {'id': 'P1005', 'city': 'TROY'},
#  {'id': 'P1019', 'city': 'WARREN'},
#  {'id': 'N8067', 'city': 'ALMONT'},
#  {'id': 'U442102125', 'city': 'ALMONT'},
#  {'id': 'U441700575', 'city': 'ALMONT'},
#  {'id': 'K2576', 'city': 'BRUCE TWP'},
#  {'id': 'B8809', 'city': 'ARMADA'},
#  {'id': 'N5696', 'city': 'ARMADA'},
#  {'id': 'B6636', 'city': 'ARMADA'},
#  {'id': 'N7047', 'city': 'ARMADA'},
#  {'id': 'P1160', 'city': 'ARMADA'},
#  {'id': 'E9903', 'city': 'NEW HAVEN'},
#  {'id': 'B6145', 'city': 'AVOCA'},
#  {'id': 'N7711', 'city': 'AVOCA'},
#  {'id': 'U631803621', 'city': 'BIRMINGHAM'},
#  {'id': 'EN6300255', 'city': 'BIRMINGHAM'},
#  {'id': 'EN6300049', 'city': 'BIRMINGHAM'},
#  {'id': 'U631509193', 'city': 'BIRMINGHAM'},
#  {'id': 'N6621', 'city': 'BLOOMFELD HLS'},
#  {'id': 'B6481', 'city': 'CAPAC'},
#  {'id': 'M3423', 'city': 'CAPAC'},
#  {'id': 'U741612777', 'city': 'MUSSEY TOWNSHIP'},
#  {'id': 'B8337', 'city': 'MUTTONVILLE'},
#  {'id': 'N5107', 'city': 'CENTER LINE'},
#  {'id': 'B6379', 'city': 'CENTER LINE'},
#  {'id': 'EN5000053', 'city': 'CENTER LINE'},
#  {'id': 'N2828', 'city': 'STERLING HTS'},
#  {'id': 'A5095', 'city': 'CLAWSON'}]

# %%
# Turning the two lists of dictionaries into dataframes so I can concatenate them.
cities1 = pd.DataFrame(cities1)
cities2 = pd.DataFrame(cities2)
frames = [cities1, cities2]
cities_combined = pd.concat(frames, keys=["id", "city"], ignore_index=True)
cities_combined
# Out:
#               id         city
# 0          N8277        AKRON
# 1          N8274        AKRON
# 2      U04060035       ALPENA
# 3          N7824     BELLAIRE
# 4      U15060046   CHARLEVOIX
# ...          ...          ...
# 5902       P1069  ROGERS CITY
# 5903       P0067         ROCK
# 5904       N1973   PORT HURON
# 5905  U831506751     THORNTON
# 5906   U82060106          NaN
#
# [5907 rows x 2 columns]

# %%
# Realized late in the game that I had records that were the old headers for each page
# source_id became 'Source', so I filtered those out of my combined dataframe 
# and saved the filtered dataframe

cities_combined = cities_combined[cities_combined.id != 'Source']

# Without those rows I'm down to 5837 records
len(cities_combined)
# Out:
# 5837

# %%
# 3. ------------- ADDRESSES: CLEAN -------------
# Getting the addresses and the source_ids so I can merge on source_id
# Pulling them out in two sections for the same reasons as above

# Get the first 82 rows addresses
address1 = []
for index, row in df.iterrows():
    data = {}
    if index < 83:
        data['id'] = row['source_id']
        data['address'] = row['Address']
        address1.append(data)

# Get the rest of the addresses
address2 = []
for index, row in df.iterrows():
    data = {}
    if index >= 83:
        data['id'] = row['source_id']
        data['address'] = row['City']
        address2.append(data)
# Checking number of records
total = len(address1) + len(address2)
total

# %%
# Turning the two lists of dictionaries into dataframes so I can concatenate them.
address1 = pd.DataFrame(address1)
address2 = pd.DataFrame(address2)
frames = [address1, address2]
address_combined = pd.concat(frames, keys=["id", "address"], ignore_index=True)
address_combined
# Out:
#               id                        address
# 0          N8277       SE SW SW SEC 19 T14N R8E
# 1          N8274       SW SW SW SEC 24 T14N R7E
# 2      U04060035                  ALPENA COUNTY
# 3          N7824  SW 1/4 NE 1/4 SEC 12 T30N R8W
# 4      U15060046              CHARLEVOIX COUNTY
# ...          ...                            ...
# 5902       P1069              1035 CALCITE ROAD
# 5903       P0067       15524 NORTH ROCK 38TH RD
# 5904       N1973    BLUE WATER BRIDGE & GRATIOT
# 5905  U831506751      18100 SOUTH INDIAN AVENUE
# 5906   U82060106                            NaN
#
# [5907 rows x 2 columns]

# %%
# Filtering out the rows of repeated headers
address_combined = address_combined[address_combined.id != 'Source']
len(address_combined)
# Out:
# 5837

# %%
# ------------- 4. NAME: CLEAN -------------
# Get company names and the source_id so I can merge on source source_id
# Doing in two chunks because it appears randomly throughout the table, Camelot
# Combined the source id and company name in one column
# The rest of the time it put company name in the address column
import re
company_names1 = []
# Replaced the "\n" I had inserted so I could get the full company name with regex
for line in df['Source ID\nCompany'].str.replace("\n", " "):
    data = {}
    # Finding the source_id
    try:
        data['id'] = re.findall("\w\w\d+", line)[0]
    except:
        data['id'] = "NaN"
    # Finding the company namename
    try:
        data['name'] = re.findall(r"\d (.*)", line)[0]
    except:
        data['name'] = "NaN"
    # I only want to save the results where the name is not NaN or Company
    if data['name'] != "NaN" and data['name'] != "Company":
        company_names1.append(data)
company_names1
# Out:
# [{'id': 'N8277', 'name': 'TUSCOLA ENERGY INC - RUMBLE SHARP CTB'},
#  {'id': 'N8274', 'name': 'TUSCOLA ENERGY INC-BOYCE JR TRUSTEE 1&STREETER 1'},
#  {'id': 'U04060035', 'name': 'UNKNOWN'},
#  {'id': 'N7824', 'name': 'RIVERSIDE - FOREST HOME 12'},
#  {'id': 'U15060046', 'name': 'UNKNOWN'},
#  {'id': 'N7833', 'name': 'MUSKEGON DEVELOPMENT, ROUND LAKE FACILITY'},
#  {'id': 'P0195', 'name': 'MUSKEGON OPERATING COMPANY, LLC - GINGEL LAKE'},
#  {'id': 'N7813', 'name': 'RIVERSIDE - OTSEGO LAKE 12 (PART OF CHESTER 7)'},
#  {'id': 'N0317', 'name': 'ACME PLATING INC'},
#  {'id': 'N8199', 'name': 'SAV WELDING SERVICES'},
#  {'id': 'N7828', 'name': 'MUSKEGON DEVELOPMENT, DOVER FACILITY'},
#  {'id': 'N7832', 'name': 'MUSKEGON DEVELOPMENT, PIGEON RIVER FACILITY'},
#  {'id': 'N7476', 'name': 'PARAGON METALS'},
#  {'id': 'N8165', 'name': 'CHAMPION BUS INC'},
#  {'id': 'U341414092', 'name': 'ABANDONED COMMERCIAL BUILDING'},
#  {'id': 'U36120455', 'name': 'IRON COUNTY GENERAL'},
#  {'id': 'B8878', 'name': 'COOPER FOUNDRY INC.'},
#  {'id': 'A2110', 'name': 'PRAB CONVEYORS'},
#  {'id': 'N8227', 'name': 'R L SCHMITT CO INC'},
#  {'id': 'U561505076', 'name': '1708 E ASHMAN ST'},
#  {'id': 'U60060087', 'name': 'UNKNOWN'},
#  {'id': 'B5766', 'name': 'MINISTRELLI CONSTRUCTION CO'},
#  {'id': 'U69060095', 'name': 'UNKNOWN'},
#  {'id': 'N7834', 'name': 'MUSKEGON DEVELOPMENT, OTSEGO LAKE FACILITY'},
#  {'id': 'N3508', 'name': 'M. L.  CHARTIER INC.'},
#  {'id': 'A2098', 'name': 'SAPA ALUMINUM'},
#  {'id': 'B4721', 'name': 'MULTI FEED INC'},
#  {'id': 'N4961', 'name': 'JOHNSTON LITHOGRAPH INC.'},
#  {'id': 'A8266', 'name': 'SAINT GOBIAN ABRASIVES'},
#  {'id': 'N8190', 'name': 'HILDEN OIL CO - HAMILTON GAS PLANT'},
#  {'id': 'P0228', 'name': 'DEPT OF ENVIRONMENTAL QUALITY-RD'},
#  {'id': 'B7514', 'name': 'ST. MARYS CEMENT, INC'},
#  {'id': 'U632100200', 'name': 'FORMER LUMBER YARD'},
#  {'id': 'M4092', 'name': 'DETROIT LEAD PIPE WORKS INC'},
#  {'id': 'N2689', 'name': 'VIENNA JUNCTION LANDFILL'},
#  {'id': 'N8048', 'name': 'SPEEDWAY SUPERAMERICA (SSA 5543)'},
#  {'id': 'N8096', 'name': 'SPEEDWAY SUPERAMERICA LLC (REM SITE SSA 8754)'},
#  {'id': 'A6260', 'name': 'ALGONAC CAST PRODUCTS INC'},
#  {'id': 'N8094', 'name': 'SPEEDWAY SUPERAMERICA LLC (REM SITE SSA 8702)'},
#  {'id': 'N6769', 'name': 'SUNSATION PRODUCTS INC'},
#  {'id': 'P1024', 'name': 'ALTA EQUIPMENT COMPANY'},
#  {'id': 'U741802378', 'name': 'FORMER RESTAURANT'},
#  {'id': 'P1089', 'name': 'CARL SCHEGEL'},
#  {'id': 'P1015', 'name': 'ENBRIDGE ENERGY, LP'},
#  {'id': 'P1030', 'name': 'MCCOIG MATERIALS, LLC'},
#  {'id': 'P1147', 'name': "ST. MARY'S CEMENT, INC."},
#  {'id': 'P1001', 'name': 'SC ENVIRONMENTAL SERVICES, LLC'},
#  {'id': 'P1029', 'name': 'HAVILAND PRODUCTS COMPANY'},
#  {'id': 'P1090', 'name': 'GRAND RAPIDS CREMATORY, INC.'},
#  {'id': 'P0998', 'name': 'MI GRAVEL DBA TCA MANAGEMENT LLC'},
#  {'id': 'P1083', 'name': 'AMERICAN STATE EQUIPMENT'},
#  {'id': 'P1091', 'name': 'EXOTIC RUBBER & PLASTICS'},
#  {'id': 'P1112', 'name': 'MAYZIE, INC. DBA PET PASSAGES'},
#  {'id': 'P1000', 'name': 'QUALITY ROASTING, LLC'},
#  {'id': 'P1016', 'name': 'GREAT LAKES AGGREGATES - LIPPMANN PLANT'},
#  {'id': 'P1005', 'name': 'INDEPENDENCE EXCAVATING'},
#  {'id': 'P1019', 'name': 'GROUND EFFECTS, LLC'},
#  {'id': 'N8067', 'name': 'ARISTO CAST'},
#  {'id': 'U442102125', 'name': "NOVAK'S SUPPLY AND EQUIPMENT"},
#  {'id': 'U441700575', 'name': 'VACANT BUILDING'},
#  {'id': 'K2576', 'name': 'HENRY FORD MACOMB HEALTH CENTER -BRUCE TOWNSHIP'},
#  {'id': 'B8809', 'name': 'ARMADA GRAIN'},
#  {'id': 'N5696', 'name': 'ARMADA RUBBER MANUFACTURING CO'},
#  {'id': 'B6636', 'name': 'CONSUMERS ENERGY - RAY COMPRESSOR STATION'},
#  {'id': 'N7047', 'name': 'HILCO TECHNOLOGIES'},
#  {'id': 'P1160', 'name': 'KRAUSE VETERINARY CLINIC'},
#  {'id': 'E9903', 'name': 'HOLSBEKE CONSTRUCTION, INC.'},
#  {'id': 'B6145', 'name': 'DTE ELECTRIC COMPANY - GREENWOOD ENERGY CENTER'},
#  {'id': 'N7711', 'name': 'RGE AGGREGATES'},
#  {'id': 'U631803621', 'name': 'COMMERCIAL BUILDING'},
#  {'id': 'EN6300255', 'name': 'ETON CLEANERS'},
#  {'id': 'EN6300049', 'name': 'GRANT STREET CLEANERS'},
#  {'id': 'U631509193', 'name': 'QUALITY COACH COLLISION'},
#  {'id': 'N6621', 'name': 'DETROIT WATER & SEWERAGE, ADAMS ROAD STATION'},
#  {'id': 'B6481', 'name': 'ANR PIPELINE COMPANY - CAPAC COMPRESSOR STATION'},
#  {'id': 'M3423', 'name': 'CAPACFARMERS ELEVATOR CO'},
#  {'id': 'U741612777', 'name': 'FORMER CAPAC STORAGE'},
#  {'id': 'B8337', 'name': 'ANR PIPELINE CO.-MUTTONVILLE COMPRESSOR STATION'},
#  {'id': 'N5107', 'name': 'CREST FORD, INC.'},
#  {'id': 'B6379', 'name': 'SODECIA NORTH AMERICA'},
#  {'id': 'EN5000053', 'name': 'VAN DYKE CLEANERS'},
#  {'id': 'N2828', 'name': 'COMPASS WHOLESALE TIRES & CAR PARTS'},
#  {'id': 'A5095', 'name': 'CREATIVE SOLUTIONS GROUP, INC.'},
#  {'id': 'U631800016', 'name': 'RESIDENCE'},
#  {'id': 'U632100705', 'name': 'VACANT RESIDENTIAL'},
#  {'id': 'U631603918', 'name': 'FORMER THUNDERBIRD LANES'},
#  {'id': 'U501807378', 'name': 'KEM-TEC LAND SURVEYORS'},
#  {'id': 'U741708252', 'name': 'FORMER ZLATES PLACE'},
#  {'id': 'U742001992', 'name': 'MALLARD POND CONSTRUCTION'},
#  {'id': 'U501705432', 'name': "FORMER BALLEW'S BAR & GRILL"},
#  {'id': 'U741611695', 'name': "CONRAD'S POULTRY FARM"},
#  {'id': 'U631501656', 'name': 'CAPITAL SALES COMPANY'},
#  {'id': 'U631610826', 'name': 'COMMERCIAL BUILDING'},
#  {'id': 'U631501658', 'name': 'MICHIGAN SPLINE GAGE COMPANY'},
#  {'id': 'U632103936', 'name': 'VACANT RESIDENTIAL'},
#  {'id': 'U631502761', 'name': 'ACTION IMPACT, INC.'},
#  {'id': 'U631807777', 'name': 'BUSCHE PERFORMANCE GROUP'},
#  {'id': 'U501501390', 'name': 'A & D INDUSTRIES'},
#  {'id': 'U631707525', 'name': 'BENDIX CORP'},
#  {'id': 'U741600997',
#   'name': 'ENBRIDGE, INC.-MARYVILLE TAKE OFF METERING STATION'},
#  {'id': 'U741608785', 'name': 'PAUMAC TUBING LLC'},
#  {'id': 'U742102897', 'name': 'SEAWAY MOBILE HOME RANCH'},
#  {'id': 'U501611367', 'name': 'DANLYN CONTROLS'},
#  {'id': 'U501501917', 'name': 'GREAT LAKES CUSTOMS'},
#  {'id': 'U501700825', 'name': 'ANCHOR BAY PACKAGING CORPORATION'},
#  {'id': 'U501601738', 'name': 'EBBCO INC'},
#  {'id': 'U502100242', 'name': 'FORMER BAKERY'},
#  {'id': 'U501601736', 'name': 'KBE PRECISIONS PRODUCTS, LLC'},
#  {'id': 'U501505836', 'name': 'ESPER GRAIN, LLC'},
#  {'id': 'U501501393', 'name': 'ATTICA HYDRAULIC EXCHANGE, INC.'},
#  {'id': 'U501604278', 'name': 'ELITE FENCE PRODUCTS INC'},
#  {'id': 'U502004021', 'name': 'APPLIED TECH INDUSTRIES'},
#  {'id': 'U631908774', 'name': 'SEAMEN MANUFACTURING COMPANY'},
#  {'id': 'U741601170', 'name': 'RESIDENCE'},
#  {'id': 'U742103434', 'name': 'TECHNI-COMP ENVIRONMENTAL'},
#  {'id': 'U742103890', 'name': 'VACANT COMMERCIAL'},
#  {'id': 'U742000292', 'name': 'VACANT HOTEL'},
#  {'id': 'U741611176', 'name': 'CROWN GROUP, PT. HURON'},
#  {'id': 'U502000395', 'name': 'VACANT COMMERCIAL BUILDING'},
#  {'id': 'U502001810', 'name': 'FORMER CLUBHOUSE'},
#  {'id': 'U501801646', 'name': 'UNKNOWN'},
#  {'id': 'U501809157', 'name': 'D&D MACHINERY MOVERS'},
#  {'id': 'U501906362', 'name': 'FRANK BIZZOCCHI CEMENT CONSTRUCTION'},
#  {'id': 'U501807309', 'name': 'QUALITY TEXTURES'},
#  {'id': 'U501704880', 'name': 'SEARS #1450'},
#  {'id': 'U631512639', 'name': 'AMBER CROSSING EAST APARTMENTS'},
#  {'id': 'U631501527', 'name': 'WING PATTERN'},
#  {'id': 'U631601864', 'name': 'HENKEL CORPORATION-MADISON HEIGHTS FACILITY'},
#  {'id': 'U631501295', 'name': 'AROBOTECH SYSTEMS, INC.'},
#  {'id': 'U631501526', 'name': 'BARON INDUSTRIES'},
#  {'id': 'U631500948', 'name': 'BRASCO INTERNATIONAL, INC.'},
#  {'id': 'U631504719', 'name': 'MOBILITY WORKS'},
#  {'id': 'U631501415', 'name': 'QCR TECH'},
#  {'id': 'U632104211', 'name': 'FUTURE PARKING LOTS FOR ADDRESS BELOW'},
#  {'id': 'U631800657', 'name': 'BP GAS STATION - COOLIDGE MART INC.'},
#  {'id': 'U631703385', 'name': 'FIRE DEFENSE EQUIPMENT COMPANY, INC.'},
#  {'id': 'U631809155', 'name': 'H.A. KING'},
#  {'id': 'U631508688', 'name': 'MAC CONSTRUCTION, INC.'},
#  {'id': 'U631510427', 'name': 'UNITED RESIN CORPORATION'},
#  {'id': 'U741807773', 'name': 'CARRYER PICTURE FRAMES'},
#  {'id': 'U631910206', 'name': 'COMMERCIAL BUILDING'},
#  {'id': 'U632104247', 'name': 'SOUTHFIELD POLICE BUILDING'},
#  {'id': 'U632100334', 'name': 'UNKNOWN SOURCE NEAR 8 MILE RD. AND LAHSER RD.'},
#  {'id': 'U632002056', 'name': 'VACANT APARTMENT BUILDING'},
#  {'id': 'U632003160', 'name': 'VACANT COMMERCIAL STRUCTURRE'},
#  {'id': 'U631909932', 'name': 'VACANT COMMERCIAL PROPERTY'},
#  {'id': 'U741801703', 'name': 'BUILDING'},
#  {'id': 'U741416277', 'name': 'CARSON FABRICATION COMPANY'},
#  {'id': 'U742103161', 'name': 'COMMERCIAL LOT'},
#  {'id': 'U821905626', 'name': 'FORMER ALLIED AUTOMOTIVE TECHNICAL CENTER'},
#  {'id': 'U631809167', 'name': 'FORMER TACO BELL'},
#  {'id': 'U822001281', 'name': 'BELLE TIRE'},
#  {'id': 'U631801609', 'name': 'TERMINAL SUPPLY CO.'},
#  {'id': 'U631500569', 'name': 'US FARATHANE CORPORATION (USF)'},
#  {'id': 'U631809314', 'name': 'RESIDENCE'},
#  {'id': 'U631810776', 'name': 'RESIDENCE'},
#  {'id': 'U631809310', 'name': 'RESIDENTIAL BUILDING'},
#  {'id': 'U501908603', 'name': "SHANNY'S MATERIALS INC"},
#  {'id': 'U501508846', 'name': "CAL'S AUTO TECH"},
#  {'id': 'U501508249', 'name': 'DIVISION 6 FABRICATION AND INSTALLATION LLC'},
#  {'id': 'U501908479', 'name': 'FORMER FOUNDRY'},
#  {'id': 'U501810303', 'name': 'FORMER WRIGHT AND FILIPPIS BUILDING'},
#  {'id': 'U822105024', 'name': "HITCHIN' POST BAR"},
#  {'id': 'U501506678', 'name': 'HOOVER COLLISION'},
#  {'id': 'U501410988',
#   'name': 'MITSUBISHI CHEMICAL PERFORMANCE POLYMERS, INC.'},
#  {'id': 'U821703942', 'name': 'FORMER GAS STATION'},
#  {'id': 'U501509175', 'name': 'CHATTERTON MIDDLE SCHOOL'},
#  {'id': 'U501701201', 'name': 'COMMERCIAL BUILDING'},
#  {'id': 'U501505631', 'name': 'FITZGERALD HIGH SCHOOL'},
#  {'id': 'U501809156', 'name': 'FUTURA CUSTOM KITCHENS'},
#  {'id': 'U501507253', 'name': 'GENEX WINDOW, INC.'},
#  {'id': 'U502001005', 'name': 'MOHAWK PLAZA'},
#  {'id': 'U631415566', 'name': 'WASTE FREE, LLC'},
#  {'id': 'U631502345', 'name': 'BP GAS STATION'},
#  {'id': 'U501702090', 'name': 'COMERICA BANK BUILDING'},
#  {'id': 'U501909799', 'name': 'HOOVER ROAD STORAGE CENTER LLC'},
#  {'id': 'U501512796',
#   'name': 'ROAD WAY INN HOTEL    /  WOODHAVEN ENTERPRISES INC'},
#  {'id': 'U502004149', 'name': 'CERTIFIED MOTORS'},
#  {'id': 'U501505926', 'name': 'VOGELSBERG GRAIN COMPANY'},
#  {'id': 'U811802278', 'name': 'COMMERCIAL BUILDING'},
#  {'id': 'U811802116', 'name': 'VACANT BUILDING'},
#  {'id': 'U812000244', 'name': 'VACANT RESIDENCE'},
#  {'id': 'U812100347', 'name': 'ANN ARBOR WOODS'},
#  {'id': 'U812105401', 'name': 'FORMER STATE FARM INSURANCE'},
#  {'id': 'U811902562', 'name': 'RESIDENCE'},
#  {'id': 'U822002320', 'name': 'FORMER LAKEVIEW TAVERN'},
#  {'id': 'U822100553', 'name': 'VACANT COMMERCIAL STRUCTURE'},
#  {'id': 'U471703377', 'name': 'COMMERCIAL OFFICE BUILDING'},
#  {'id': 'U471509357', 'name': 'PHOENIX POLYMER COMPOUNDING LLC'},
#  {'id': 'U471803725', 'name': 'VACANT APARTMENTS'},
#  {'id': 'U581706408', 'name': 'RAM INDUSTRIES'},
#  {'id': 'U811612393', 'name': 'COMMERCIAL BUILDING'},
#  {'id': 'U821902769', 'name': 'FORMER NURSING HOME'},
#  {'id': 'U821806193', 'name': 'OAKWOOD FOOD CENTER'},
#  {'id': 'U821707516', 'name': 'FORMER BIG BOY'},
#  {'id': 'U821610264', 'name': 'RESIDENCE'},
#  {'id': 'U822000248', 'name': 'VACANT RESIDENCE'},
#  {'id': 'U821704604', 'name': 'APARTMENT BUILDINGS'},
#  {'id': 'U821809940', 'name': 'RESIDENTIAL PROPERTY'},
#  {'id': 'U821705423', 'name': 'COMMERCIAL STRUCTURE'},
#  {'id': 'U821607716', 'name': 'RESIDENCE'},
#  {'id': 'U821612160', 'name': 'RESIDENCE'},
#  {'id': 'U821600290', 'name': 'SHAMA ENTERPRISES, INC. - FIRBIRD GAS STATION'},
#  {'id': 'U821608788', 'name': 'FORMER CHURCH'},
#  {'id': 'U811905509', 'name': 'BULLION SALES INC.'},
#  {'id': 'U822001288', 'name': 'BIG BOY'},
#  {'id': 'U822000580', 'name': 'VACANT COMMERCIAL PROPERTY'},
#  {'id': 'U471604422',
#   'name': 'MONROE RUBBISH- EQUIPMENT STORAGE AND PAINT BOOTH'},
#  {'id': 'U471604420', 'name': 'MONROE RUBBISH- TRANSFER STATION'},
#  {'id': 'U821906565', 'name': 'VACANT BUILDING'},
#  {'id': 'U822002387', 'name': 'VACANT COMMERCIAL BUILDINGS'},
#  {'id': 'U821704329', 'name': 'FORMER VFW CPL LAMBERT PFEIFFER POST'},
#  {'id': 'U821611421', 'name': 'CLOVERLANES BOWL'},
#  {'id': 'U821510261', 'name': 'OKERSTROM BUILDING'},
#  {'id': 'U821709459', 'name': 'BJS RESTAURANT'},
#  {'id': 'U821609511', 'name': 'HOLMES MIDDLE SCHOOL'},
#  {'id': 'U812100043', 'name': 'FORMER YORKTOWN LIQUOR'},
#  {'id': 'U581701232',
#   'name': 'COMMERCIAL BUILDING WITH 6 ATTACHED APARTMENTS'},
#  {'id': 'U581611031', 'name': 'FORMER FRIENDLY FORD DEALERSHIP'},
#  {'id': 'U581607696', 'name': 'SOUTH MONROE ELEMENTARY SCHOOL'},
#  {'id': 'U582102229', 'name': 'FORMER MOBIL GAS STATION'},
#  {'id': 'U582102231', 'name': 'FORMER RESTAURANT'},
#  {'id': 'U821808210', 'name': 'WALTZ RD. BRIDGE'},
#  {'id': 'U631610743', 'name': 'CUMMINS BRIDGEWAY'},
#  {'id': 'U631501703', 'name': 'KENTUCKY TRAILOR TECHNOLOGIES'},
#  {'id': 'U631611951',
#   'name': 'MARADA INDUSTRIES, INC.DBA COSMA BODY AND ASSEMBLY'},
#  {'id': 'U631500414', 'name': 'USA-2-GO SUNOCO'},
#  {'id': 'U582101894', 'name': 'VACANT COMMERCIAL'},
#  {'id': 'U501809584', 'name': 'DONATO ENTERPRISES'},
#  {'id': 'U631907801', 'name': 'NORTHVILLE LUMBER COMPANY'},
#  {'id': 'U632002511', 'name': 'VACANT RESIDENCE'},
#  {'id': 'U472103784', 'name': 'THE MEANS PROJECT'},
#  {'id': 'U822102899', 'name': 'FORMER GARDEN CENTER'},
#  {'id': 'U822105073', 'name': 'VACANY COMMERCIAL'},
#  {'id': 'U821904222', 'name': "FORMER MAX & ERMA'S RESTARAUNT"},
#  {'id': 'U822102076', 'name': 'COMMERCIAL/RESIDENTIAL MIXED'},
#  {'id': 'U821604667', 'name': 'RESIDENCE'},
#  {'id': 'U821809943', 'name': 'MPC LP TERMINAL ROMULUS'},
#  {'id': 'U811700247', 'name': 'SALINE COMMONS'},
#  {'id': 'U631500167', 'name': 'SOUTH LYON GRAIN ELEVATOR'},
#  {'id': 'U631612572', 'name': 'SOUTH LYON HOTEL'},
#  {'id': 'U821803866', 'name': 'COMMERCIAL BUILDING'},
#  {'id': 'U821606386', 'name': 'PAR WICK PHARMACY'},
#  {'id': 'U821508779', 'name': 'RAMADA HOTEL'},
#  {'id': 'U821606385', 'name': 'RESIDENCE'},
#  {'id': 'U821505694', 'name': 'VACANT BUILDING'},
#  {'id': 'U821705360', 'name': 'WAHLBURGERS TAYLOR LLC'},
#  {'id': 'U821810662', 'name': 'FORMER MCLOUTH STEEL'},
#  {'id': 'U821512947', 'name': 'FORMER KMART'},
#  {'id': 'U821702368', 'name': 'FORMER UNIQUE SUPER TAN'},
#  {'id': 'U822002450', 'name': 'FORMER 112 BAR'},
#  {'id': 'U821802926', 'name': 'COMMERCIAL BUILDING'},
#  {'id': 'U821910547', 'name': 'COMMERCIAL PROPERTY'},
#  {'id': 'U822101831', 'name': 'DYE BROS'},
#  {'id': 'U822004064', 'name': 'VACANT RESIDENCE'},
#  {'id': 'U811700638', 'name': 'FORMER HOMETOWN BICYCLES SHOP'},
#  {'id': 'U812101845', 'name': 'VACANT APARTMENT'},
#  {'id': 'U811810016', 'name': 'VACANT SCHEDULED FOR DEMO'},
#  {'id': 'U822100055', 'name': 'APARTMENT BUILDING'},
#  {'id': 'U822000003', 'name': 'FORMER WYANDOTTE POST OFFICE'},
#  {'id': 'U822103219', 'name': 'VACANT COMMERCIAL PROPERTY'},
#  {'id': 'U821805784', 'name': 'DOWNRIVER CONEY ISLAND'},
#  {'id': 'U821701106', 'name': 'MORAN AUTOMOTIVE SERVICE CENTER'},
#  {'id': 'U821910201', 'name': 'OLD GAS STATION'},
#  {'id': 'U821905094', 'name': 'COMMERCIAL BUILDING'},
#  {'id': 'U581706430', 'name': 'CARLETON IRON & METALS'},
#  {'id': 'U811810208', 'name': 'THURSTON ELEMENTARY'},
#  {'id': 'U811606419', 'name': 'VACANT RESIDENCE'},
#  {'id': 'U811706525', 'name': 'A-1 AUTO SALVAGE & SCRAP'},
#  {'id': 'U811513295', 'name': 'BURGER KING'},
#  {'id': 'U811510952', 'name': 'VACANT STRUCTURE'},
#  {'id': 'U821700029', 'name': 'APARTMENT BUILDING'},
#  {'id': 'U821803612', 'name': 'THE MASONIC TEMPLE'},
#  {'id': 'U822003560', 'name': 'WAYNE COURT APARTMENTS'},
#  {'id': 'U821801431', 'name': 'APARTMENT BUILDING'},
#  {'id': 'U822000579', 'name': 'APARTMENT BUILDING'},
#  {'id': '
#  {'id': 'U631600672', 'name': 'BAE INDUSTRIES, INC.'},
#  {'id': 'U631410488',
#   'name': 'CONTINENTAL AUTOMOTIVE SYSTEMS HARMON ROAD FACILIT'},
#  {'id': 'U631609998', 'name': 'GKN DRIVELINE'},
#  {'id': 'U631800435', 'name': 'HIRSCHMANN CAR COMMUNICATION, INC.'},
#  {'id': 'U631500012', 'name': 'HUTCHINSON FTS AND HUTCHINSON SEALING SYSTEMS'},
#  {'id': 'U631504917', 'name': 'MUNRO & ASSOCIATES, INC.'},
#  {'id': 'U631800436', 'name': 'PUNATI CHEMICALS CORPORATION'},
#  {'id': 'U631708326', 'name': 'TRANSIGN, LLC'},
#  {'id': 'U631810653', 'name': 'HOUSE - OFFICE USE'},
#  {'id': 'U631605281', 'name': 'TOMATO KITCHEN'},
#  {'id': 'U631509495', 'name': 'MOBIL GAS STATION'},
#  {'id': 'U631602211', 'name': 'AUTONEUM NORTH AMERICA, INC.'},
#  {'id': 'U631511780', 'name': 'BROOKS UTILITY PRODUCTS'},
#  {'id': 'U631601378', 'name': 'ELECTRO-MATIC PRODUCTS, INC.'},
#  {'id': 'U631705228', 'name': 'ERHARD BMW OF FARMINGTON HILLS'},
#  {'id': 'U631513520', 'name': 'FIVES CINETIC CORP.'},
#  {'id': 'U631611144', 'name': 'KERN-LIEBERS USA, INC.'},
#  {'id': 'U631512533', 'name': 'PREMIER FURNACE SPECIALISTS, INC.'},
#  {'id': 'U631507541', 'name': 'DMI'},
#  {'id': 'U632003941', 'name': 'FORMER GAS STATION STOREFRONT'},
#  {'id': 'U631507548', 'name': 'THE OLD WINERY'},
#  {'id': 'U631802498', 'name': 'AR GLOBAL / TREMEC'},
#  {'id': 'U632002012', 'name': 'VACANT RESIDENCE'},
#  {'id': 'U631906759', 'name': 'APARTMENT BUILDING'},
#  {'id': 'U631808141', 'name': 'FORMER SALVATION ARMY BUILDING'},
#  {'id': 'U631708771', 'name': 'RESIDENCE'},
#  {'id': 'U632001904', 'name': 'AMAZON FULFILLMENT CENTER'},
#  {'id': 'U632001529', 'name': 'FORMER GLENWOOD PLAZA'},
#  {'id': 'U631802377', 'name': 'PEDESTRIAN BRIDGE'},
#  {'id': 'U631611912', 'name': 'RIKER BUILDING'},
#  {'id': 'U631801190', 'name': 'WEST MANOR'},
#  {'id': 'U081704224', 'name': 'RESIDENCE'},
#  {'id': 'U081704225', 'name': 'RESIDENCE'},
#  {'id': 'U631904933', 'name': 'BOWMAN AUTO CENTER'},
#  {'id': 'U472102469', 'name': 'RESIDENCE'},
#  {'id': 'U821803315', 'name': 'FORMER HIGHLAND HOUSE RESTAURANT'},
#  {'id': 'U631610016', 'name': 'US FARATHANE LAKE ORION'},
#  {'id': 'U631701620', 'name': 'DURR SYSTEMS, INC.'},
#  {'id': 'U631500726', 'name': 'EBERSPAECHER NORTH AMERICA, INC.'},
#  {'id': 'U632003148', 'name': 'AUTONEUM NORTH AMERICA, INC.'},
#  {'id': 'U631510437', 'name': 'TOYOTA BOSHOKU AMERICA, INC.'},
#  {'id': 'U631909070', 'name': 'SAVOY ENERGY'},
#  {'id': 'U631700103', 'name': 'AMERICAN EXPEDITION VEHICLES'},
#  {'id': 'U631505663', 'name': 'CAPITAL STAMPING AND MACHINE, INC. (CSM)'},
#  {'id': 'U631411864', 'name': 'FIREBOLT GROUP, INC.'},
#  {'id': 'U631414113', 'name': 'GLASS AND MIRROR CRAFT INDUSTRIES'},
#  {'id': 'U631505636', 'name': 'GRAND STEEL PRODUCTS, INC.'},
#  {'id': 'U631415315', 'name': 'HALLITE SEALS AMERICA, INC.'},
#  {'id': 'U631505748', 'name': 'HALLMARK TOOL & GAUGE COMPANY, INC.'},
#  {'id': 'U631501400', 'name': 'HITACHI CHEMICAL CO. AMERICA LTD.'},
#  {'id': 'U631502091', 'name': 'MATHESON'},
#  {'id': 'U631604255', 'name': 'METHODS MACHINE TOOL, INC.'},
#  {'id': 'U631413130', 'name': 'NORTHSTAR MAT SERVICE'},
#  {'id': 'U631411066', 'name': 'PPG BUSINESS DEVELOPMENT CENTER'},
#  {'id': 'U631501805', 'name': 'RAMPF GROUP, INC.'},
#  {'id': 'U631508690', 'name': 'TOMCO FABRICATION AND MACHINE, INC.'},
#  {'id': 'U631501912', 'name': 'TOYODA'},
#  {'id': 'U631501702', 'name': 'GENERAL RV CENTER'},
#  {'id': 'U321501345', 'name': 'FLANNERY AUTO MALL'},
#  {'id': 'U441508535', 'name': 'HOMER CONCRETE PRODUCTS'},
#  {'id': 'U641800688', 'name': 'STROAGE UNIT'},
#  {'id': 'U762103183', 'name': 'CITY OF CROSWELL'},
#  {'id': 'U762101623', 'name': 'MICHIGAN SUGAR - CROSWELL PLANT'},
#  {'id': 'U251607791', 'name': 'DAVISON SENIOR HIGH SCHOOL'},
#  {'id': 'U251806729', 'name': 'FERNCO'},
#  {'id': 'U761701182', 'name': 'PALMER FARMS INC.'},
#  {'id': 'U782101017', 'name': 'RESTAURANT'},
#  {'id': 'U471810310', 'name': 'RESIDENTIAL PROPERTY'},
#  {'id': 'U251607768',
#   'name': "VG'S GROCERY (FORMER TOMS SUPER MARKET OF GENESEE)"},
#  {'id': 'U251612652', 'name': 'GENESEE CARE CENTER'},
#  {'id': 'U251612653', 'name': 'MEDILODGE OF GRAND BLANC'},
#  {'id': 'U631804737', 'name': 'SOUTH FLINT GRAVEL'},
#  {'id': 'U631908780', 'name': 'STABLEX CORPORATION'},
#  {'id': 'U441708621',
#   'name': "SUMMERS ROAD GRAVEL & DEV./NOVAK'S SUPPLY & EQUIP"},
#  {'id': 'U782101581', 'name': 'RESIDENCE'},
#  {'id': 'U762002643', 'name': 'COTTAGE'},
#  {'id': 'U761603049', 'name': 'SAFETY ENGINEERING LABS'},
#  {'id': 'U251802280', 'name': 'ARISTEO INSTALLATION LLC'},
#  {'id': 'U251704046', 'name': 'FORMER OLD SCHOOLHOUSE'},
#  {'id': 'U251805357', 'name': 'MULTIBLAST ENVIRONMENTALLY SAFE STRIPPING INC'},
#  {'id': 'U251612585',
#   'name': 'WATER AND WASTE SERVICES, GENESEE COUNTY, MONTROSE'},
#  {'id': 'U441414296', 'name': 'NORTH BRANCH SANDBLASTING'},
#  {'id': 'U321502629', 'name': 'GRINDSTONE PROPERTIES LLC- PORT AUSTIN'},
#  {'id': 'U761509834', 'name': 'ARGYLE TOWNSHIP FIRE DEPARTMENT FIRE TRAINING'},
#  {'id': 'U251602578', 'name': 'ELMS ROAD ELEMENTARY'},
#  {'id': 'U252003618', 'name': 'FORMER SWARTZ CREEK ELEVATOR'},
#  {'id': 'U251603131', 'name': 'FLINT MAIN POST OFFICE'},
#  {'id': 'U252105090', 'name': 'COMMERICAL BLDG'},
#  {'id': 'U251603134', 'name': 'MOTT MIDDLE COLLEGE'},
#  {'id': 'U251606515',
#   'name': 'NORTHWESTERN PREPARATORY ACAD (FLINT COMM SCHOOLS)'},
#  {'id': 'U251804380', 'name': 'RESIDENCE'},
#  {'id': 'U251703600', 'name': 'VACANT STRUCTURE'},
#  {'id': 'U251606516', 'name': 'MCDONALDS, CLIO RD'},
#  {'id': 'U251607776',
#   'name': 'TREASURE ENTERPRISES, FORMERLY WOOLCO DEPT STORE'},
#  {'id': 'U251512119', 'name': 'GENESEE RECYCLING'},
#  {'id': 'U251903057', 'name': 'RESIDENTIAL'},
#  {'id': 'U251903138', 'name': 'VACANT HOUSE'},
#  {'id': 'U251709179', 'name': 'ATTENTIVE INDUSTRIES, INC.'},
#  {'id': 'U251509020',
#   'name': 'MARATHON CONSTRUCTION (DELPHI FLINT EAST, PLT. 6)'},
#  {'id': 'U251603133', 'name': 'MCDONALDS'},
#  {'id': 'U251612628', 'name': 'RESIDENCE'},
#  {'id': 'U251603583',
#   'name': 'GENESEE INTERM. SCHOOL DIST- GEN. CAREER INSTITUTE'},
#  {'id': 'U251606517', 'name': 'MCDONALDS, MILLER RD'},
#  {'id': 'U251610720', 'name': 'SUNRIDGE APARTMENTS'},
#  {'id': 'U251602576', 'name': 'FEDERALS DEPARTMENT STORE'},
#  {'id': 'U251607803', 'name': 'ATHERTON HIGH SCHOOL'},
#  {'id': 'U251607811', 'name': 'MADISON ACADEMY'},
#  {'id': 'U251607808', 'name': 'MANLEY SCHOOL'},
#  {'id': 'U251602577', 'name': 'ST NICHOLAS ORTHODOX CHURCH'},
#  {'id': 'U251415919', 'name': 'MJ MANUFACTURING COMPANY'},
#  {'id': 'U251701308', 'name': 'MR. KLEAN'},
#  {'id': 'U251604247', 'name': 'SOROC PRODUCTS'},
#  {'id': 'U251612638', 'name': "FLYNN'S UNITED ASPHALT PLANT AND PAVING, INC"},
#  {'id': 'U251809624',
#   'name': 'GENESEE CO. DRAIN COMMISIONER, WATER & WASTE SERV.'},
#  {'id': 'U251703574', 'name': 'VACANT STRUCTURE'},
#  {'id': 'U731601354', 'name': 'SAGINAW  COUNTY LANDBANK'},
#  {'id': 'U731903119', 'name': 'FORMER HOTEL'},
#  {'id': 'U731802333', 'name': 'RESIDENCE'},
#  {'id': 'U731905898', 'name': 'RESIDENCE'},
#  {'id': 'U731905903', 'name': 'RESIDENCE'},
#  {'id': 'U731905909', 'name': 'RESIDENCE'},
#  {'id': 'U731905914', 'name': 'RESIDENCE'},
#  {'id': 'U732001366', 'name': 'SAGINAW VILLAS MHP'},
#  {'id': 'U731608070', 'name': 'BLISS PARK'},
#  {'id': 'U732000334', 'name': 'FORMER COMMERCIAL OUTREACH BUILDING'},
#  {'id': 'U731708432', 'name': 'RESIDENCE'},
#  {'id': 'U731709334', 'name': 'RESIDENCE'},
#  {'id': 'U731801332', 'name': 'RESIDENCE'},
#  {'id': 'U731509073', 'name': 'SAGINAW COUNTY LAND BANK'},
#  {'id': 'U732001669', 'name': 'BUILDING'},
#  {'id': 'U731702262', 'name': "ENGEL'S AUTO BODY & SALES"},
#  {'id': 'U731906037', 'name': 'RESIDENCE'},
#  {'id': 'U261609015', 'name': 'OLD BEAVERTON GEM THEATER'},
#  {'id': 'U182003351', 'name': 'RESIDENCE'},
#  {'id': 'U681909284', 'name': 'FAIRVIEW FIRE DEPARTMENT BUILDING'},
#  {'id': 'U681800241', 'name': "GASCHO'S SAWMILL -N2190"},
#  {'id': 'U731707600', 'name': 'FORMER MARATHON GAS STATION'},
#  {'id': 'U731807626', 'name': 'MURRAY PAINTING COMPANY'},
#  {'id': 'U262104352', 'name': 'AMERIHEMP INC'},
#  {'id': 'U261612695', 'name': 'GLADWIN COUNTY LAND BANK'},
#  {'id': 'U562001968', 'name': 'BUILDING'},
#  {'id': 'U561700877', 'name': 'RESIDENCE'},
#  {'id': 'U561700880', 'name': 'RESIDENCE'},
#  {'id': 'U562002734', 'name': 'SUBJECT COMMERICAL BUILDING'},
#  {'id': 'U682101706', 'name': 'COMMERICIAL PROPERTY'},
#  {'id': 'U092106022', 'name': 'COMMERICAL BUILDING'},
#  {'id': 'U651411167', 'name': 'AGILITY PHYSICAL THERAPY'},
#  {'id': 'U651907799', 'name': 'CRAWFORD SAND & GRAVEL'},
#  {'id': 'U652001536', 'name': 'FORMER CITGO STATION - TAHIR ALWAJIH'},
#  {'id': 'U651808494', 'name': 'MEDICAL ARTS CENTER BUILDING'},
#  {'id': 'U062000583', 'name': 'STEVE GINGERICH'},
#  {'id': 'U091600857', 'name': 'FOURNIER DEMO'},
#  {'id': 'U091801185', 'name': 'RRH DISCOUNT, INC.'},
#  {'id': 'U091803075', 'name': 'FORMER HOWARD JOHNSON RESTAURANT'},
#  {'id': 'U091904548', 'name': 'FORMER WINGS AND THINGS'},
#  {'id': 'U791904069', 'name': 'FORMER COMMERCIAL BUILDING'},
#  {'id': 'U791905424', 'name': 'FORMER COMMERCIAL BUILDING'},
#  {'id': 'U321416162', 'name': 'KROHN PROPERTY'},
#  {'id': 'U651904557', 'name': 'HILLTOP AUTO, LLC'},
#  {'id': 'U731802383', 'name': 'DAVE HAUSBACK TRUCKING, INC. (DHT)'},
#  {'id': 'U591607343', 'name': 'CHURCH'},
#  {'id': 'U591810306', 'name': 'COMMERCIAL STORAGE'},
#  {'id': 'U231504252', 'name': 'CITIZENS GRAIN ELEVATOR, LLC'},
#  {'id': 'U231609347', 'name': 'RESIDENTIAL HOME'},
#  {'id': 'U781903050', 'name': "FORMER GIGI'S BANQUET AND CATERING"},
#  {'id': 'U331706491', 'name': 'SUNRISE AGGREGATE, LLC'},
#  {'id': 'U191906575', 'name': 'SCOTT ELEMENTARY'},
#  {'id': 'U231612072', 'name': 'MICHIGAN BEAN AND SPELT, LLC'},
#  {'id': 'U191612206', 'name': 'BNM TRAILERS'},
#  {'id': 'U191908856', 'name': 'RESIDENCE'},
#  {'id': 'U292100113', 'name': 'BRUCE WALDRON EXCAVATING INC.'},
#  {'id': 'U471600371', 'name': 'VACANT GAS STATION'},
#  {'id': 'U231509358', 'name': 'FELPAUSH'},
#  {'id': 'U231508679', 'name': 'VISION COLLISION'},
#  {'id': 'U591809661', 'name': 'NORTHLAND REFRIDGERATION PLANT'},
#  {'id': 'U591609212', 'name': 'OFFICE BUILDING'},
#  {'id': 'U332000247', 'name': 'WAREHOUSE'},
#  {'id': 'U331513570', 'name': 'BOOKSHELF BOOKSTORE'},
#  {'id': 'U331605291', 'name': 'TNT POOLS'},
#  {'id': 'U471802131', 'name': 'ECS PRODUCTION'},
#  {'id': 'U471801493', 'name': 'FIRST UNITED METHODIST CHURCH'},
#  {'id': 'U471906118', 'name': 'FORMER AUTOONE'},
#  {'id': 'U472000329', 'name': 'FORMER DTE OFFICES'},
#  {'id': 'U472104243', 'name': 'FORMER INDUSTRIAL GARAGE/STORAGE'},
#  {'id': 'U471906196', 'name': 'FORMER RESIDENTIAL'},
#  {'id': 'U471706939', 'name': 'HOWELL LANDSCAPE SUPPLIES'},
#  {'id': 'U471907802', 'name': 'OSTLUND A SERVICE COMPANY'},
#  {'id': 'U471603573', 'name': 'VACANT STRUCTURE'},
#  {'id': 'U471802094', 'name': 'MARION OAKS CLUB HOUSE'},
#  {'id': 'U341600345', 'name': 'GOLDEN GRAIN FARMS'},
#  {'id': 'U341604265', 'name': 'REFORMATORY POWER PLANT'},
#  {'id': 'U342002994', 'name': 'WOLBERS POSSEHN'},
#  {'id': 'U292001852', 'name': 'BUILDING'},
#  {'id': 'U291701964', 'name': 'C & S STEEL'},
#  {'id': 'U291611168', 'name': 'SHULTS EQUIPMENT'},
#  {'id': 'U591702320', 'name': 'COMMERCIAL BUILDING'},
#  {'id': 'U591907123', 'name': 'SUBWAY RESTAURANT'},
#  {'id': 'U341504733', 'name': 'PREMIUM MACHINE  AND TOOL'},
#  {'id': 'U331907768', 'name': 'APPLIED FLOORING'},
#  {'id': 'U331907769', 'name': 'XG SCIENCES'},
#  {'id': 'U471700150', 'name': 'PRECISE FINISHING'},
#  {'id': 'U372000444', 'name': 'COMMERCIAL BUILDING'},
#  {'id': 'U371707287', 'name': 'MISSION CREEK'},
#  {'id': 'U332000142', 'name': 'VACANT BUILDING'},
#  {'id': 'U191701599', 'name': 'HANSEN QUIK STOP'},
#  {'id': 'U782102248', 'name': 'COMMERCIAL'},
#  {'id': 'U781505323', 'name': 'FUOSS GRAVEL COMPANY'},
#  {'id': 'U782002292', 'name': 'GW FRAZEUR INC'},
#  {'id': 'U781903083', 'name': 'MOWEN FUNERAL HOME'},
#  {'id': 'U781800345', 'name': 'RESIDENCE'},
#  {'id': 'U781800512', 'name': "WILLIAM'S FURNITURE & CABINETS MANUFACTURING"},
#  {'id': 'U192100898', 'name': 'COMMERICAL BUILDING - GAS STATION'},
#  {'id': 'U141908825', 'name': 'FORMER PIZZA SHOP'},
#  {'id': 'U131413817', 'name': 'WEST BAY - RUGG 1-7 CPF'},
#  {'id': 'U131412623', 'name': 'WEST BAY EXPLORATION - FOOTE 1-12 CPF'},
#  {'id': 'U131412622', 'name': 'WEST BAY EXPLORATION - HOFFMAN 1 CPF'},
#  {'id': 'U131412619', 'name': 'WEST BAY EXPLORATION - KILBOURN FARM 2-2A CPF'},
#  {'id': 'U131412620', 'name': 'WEST BAY EXPLORATION - LANGRIDGE CPF'},
#  {'id': 'U131412621', 'name': 'WEST BAY EXPLORATION - MULLETT CPF'},
#  {'id': 'U131611869', 'name': 'YINHAI RESTAURANT'},
#  {'id': 'U031902519', 'name': 'CAM FAB'},
#  {'id': 'U031902139', 'name': 'CAMFAB, INC.'},
#  {'id': 'U032004100', 'name': 'TOTAL PROPERTY MANAGEMENT'},
#  {'id': 'U391809600', 'name': 'TLR COATINGS'},
#  {'id': 'U121910249', 'name': 'FORMER COMMERCIAL'},
#  {'id': 'U391705996', 'name': 'B&S AUTO'},
#  {'id': 'U111512997', 'name': 'FOREST HALAMPKA'},
#  {'id': 'U752102615', 'name': 'COMMERCIAL PROPERTIES'},
#  {'id': 'U751704424', 'name': 'PRM TRUCKING'},
#  {'id': 'U111807431', 'name': 'VACANT BUILDING'},
#  {'id': 'U111900321', 'name': "FORMER O'MALLEYS BAR"},
#  {'id': 'U111909456', 'name': 'FORMER RESIDENTIAL HOME'},
#  {'id': 'U111905230', 'name': 'RESIDENCE'},
#  {'id': 'U111800953', 'name': 'RESIDENCE'},
#  {'id': 'U142102218', 'name': 'TOTZKE FARMS'},
#  {'id': 'U111801976', 'name': 'HIDDEN HARBOR APARTMENTS'},
#  {'id': 'U381801574', 'name': 'FORMER ANIMAL SHELTER'},
#  {'id': 'U381608050', 'name': 'M & M EXCAVATING, INC.'},
#  {'id': 'U381909151', 'name': 'TENNECO AUTOMOTIVE'},
#  {'id': 'U382000978', 'name': 'FORMER NURSING HOME'},
#  {'id': 'U382001700', 'name': 'RESIDENCE'},
#  {'id': 'U381706248', 'name': 'VACANT HOUSE'},
#  {'id': 'U381807347', 'name': 'VACANT HOUSE'},
#  {'id': 'U381906455', 'name': 'VACANT HOUSE'},
#  {'id': 'U461705796', 'name': 'R & M RECYCLING'},
#  {'id': 'U461806909', 'name': 'SHARE THE WARMTH'},
#  {'id': 'U131806642', 'name': 'CROWELL ELEMENTARY SCHOOL'},
#  {'id': 'U301801917', 'name': 'SHIERY ANIMAL CLINIC'},
#  {'id': 'U381800001', 'name': 'AIRMASTER FAN COMPANY'},
#  {'id': 'U462003089', 'name': "FORMER JERRY'S MARKET"},
#  {'id': 'U461906434', 'name': 'COMMERCIAL BUILDING'},
#  {'id': 'U461700844', 'name': 'FORMER SUN AND SNOW MARINA RETAIL STORE'},
#  {'id': 'U461611698', 'name': 'COMMERCIAL BUILDING'},
#  {'id': 'U461700171',
#   'name': 'REVIVAL COMMONS (FORMER TECUMSEH PRODUCTS FACTORY)'},
#  {'id': 'U581801084', 'name': 'TECUMSEH PRODUCTS'},
#  {'id': 'U411608702', 'name': 'PLAINS LPG SERVICES, L.P.'},
#  {'id': 'U431906841', 'name': 'STEALTHCRAFT BOATS'},
#  {'id': 'U411501986', 'name': 'SELECT TECHNOLOGIES'},
#  {'id': 'U411501992', 'name': 'SSI ELECTRONICS, INC'},
#  {'id': 'U411502038', 'name': 'STEEL CRAFT TECHNOLOGIES'},
#  {'id': 'U541905065', 'name': 'RESIDENCE'},
#  {'id': 'U231704222', 'name': 'CUSTOM CRUSHING & RECYCLING, INC'},
#  {'id': 'U412104877', 'name': "VANBEEK'S CUSTOM WOOD PRODUCTS"},
#  {'id': 'U411806449', 'name': 'ASPEN SURGICAL HILL-ROM CORPORATION'},
#  {'id': 'U411707382', 'name': 'VAN DELLEN STEEL'},
#  {'id': 'U541603888', 'name': 'CHIPPEWA LAKES COMMUNITY BUILDING'},
#  {'id': 'U411510643', 'name': 'CHAMPION DIE INCORPORATED'},
#  {'id': 'U411801449', 'name': 'TEPPANYAKI GRILL AND BUFFET - COMERCIAL'},
#  {'id': 'U412000193', 'name': 'VACANT BUILDINGS'},
#  {'id': 'U412000251', 'name': 'VARIOUS BUILDINGS'},
#  {'id': 'U031606694', 'name': 'STANDING ROCK FARM INC.'},
#  {'id': 'U621903862', 'name': 'WILBUR-ELLIS AGRIBUSINESS'},
#  {'id': 'U031704187', 'name': 'ARNSMAN EXCAVATING'},
#  {'id': 'U591900089', 'name': "POWELL'S EXCAVATING AND SEPTIC"},
#  {'id': 'U411801495', 'name': 'DSB DEVELOPMENT LLC'},
#  {'id': 'U311612743', 'name': 'APARTMENT'},
#  {'id': 'U411809962', 'name': 'COMMERCIAL INPROVED'},
#  {'id': 'U411909825', 'name': 'FORMER BOWNE CONSTRUCTION BUILDING'},
#  {'id': 'U411415555', 'name': 'PUR FORMS'},
#  {'id': 'U082103228', 'name': 'MIDDLEVILLE TOOL AND DIE CO.'},
#  {'id': 'U621810212', 'name': 'GREAT LAKES ENERGY'},
#  {'id': 'U621703843', 'name': 'VELMA MATSON ELEMENTARY'},
#  {'id': 'U411702145', 'name': 'RESIDENCE'},
#  {'id': 'U412100317', 'name': 'SINGLE STORY HOUSE'},
#  {'id': 'U411802366', 'name': 'COMMERCIAL BUILDING'},
#  {'id': 'U411703145', 'name': 'RESIDENCE'},
#  {'id': 'U031909080', 'name': 'BLASTEK LLC'},
#  {'id': 'U411906087', 'name': 'ALTERNATIVE LAWN CARE'},
#  {'id': 'U411705789', 'name': 'COMERCIAL BUSINESS'},
#  {'id': 'U032003355', 'name': 'AUTUMN ACRES FARM'},
#  {'id': 'U692105332', 'name': 'FORMER CLARK GAS STATION'},
#  {'id': 'U701500129', 'name': 'ANTERIOR QUEST'},
#  {'id': 'U701601091', 'name': 'REEVES PLASTICS'},
#  {'id': 'U621804646', 'name': 'FLOR DRI SUPPLY CO INC.'},
#  {'id': 'U701910182', 'name': 'BUILDING'},
#  {'id': 'U701810359', 'name': 'SHAPE CORPORATION'},
#  {'id': 'U701810360', 'name': 'SHAPE CORPORATION'},
#  {'id': 'U702100577', 'name': 'SINGLE FAMILY RESIDENCE'},
#  {'id': 'U411413770', 'name': 'GRAND RAPIDS GRAVEL CO.'},
#  {'id': 'U411901354', 'name': 'ACCUFORM INDUSTRIES, INC.'},
#  {'id': 'U411600217', 'name': 'KENT WELDING'},
#  {'id': 'U411512489', 'name': 'RESIDENCE'},
#  {'id': 'U411707965', 'name': 'RESIDENCE'},
#  {'id': 'U411900090', 'name': 'SPRUIT BROS.'},
#  {'id': 'U411706643', 'name': 'VALLEY CITY LINEN'},
#  {'id': 'U411906375', 'name': 'GRAND RAPIDS MAT & TOWEL'},
#  {'id': 'U411704243', 'name': 'PREGIS FILMS'},
#  {'id': 'U411806077', 'name': "DON TONO'S MEXICAN GRILL AND BAR (FORMER)"},
#  {'id': 'U411805814', 'name': 'ABC COATING COMPANY, INC.'},
#  {'id': 'U411901521', 'name': 'OUR DAILY BREAD MINISTRIES (RBC)'},
#  {'id': 'U411809575', 'name': 'STEEL CRAFT TECHNOLOGIES'},
#  {'id': 'U411802345', 'name': 'CRESCENT ELECTRIC SUPPLY COMPANY'},
#  {'id': 'U411511585', 'name': 'VIKING SPAS'},
#  {'id': 'U411910359', 'name': 'BUILDING'},
#  {'id': 'U702000992', 'name': 'WOODLAND COMMERCIAL EQUIPMENT'},
#  {'id': 'U411906384', 'name': 'WEST MICHIGAN SHARED HOSPITAL LAUNDRY'},
#  {'id': 'U411901348', 'name': 'PROFESSIONAL METAL FINISHERS'},
#  {'id': 'U412004219', 'name': 'HUYSER ASPHALT PAVING & SEALCOATING'},
#  {'id': 'U411411729', 'name': 'SCHUPAN BEVERAGE RECYCLING'},
#  {'id': 'U831415836', 'name': 'AVON PROTECTION SYSTEMS, INC.'},
#  {'id': 'U831800021', 'name': 'CADILLAC FABRICATION'},
#  {'id': 'U831807646', 'name': 'COMMERCIAL BUILDING'},
#  {'id': 'U832106234', 'name': 'COMMERICAL BUILDING'},
#  {'id': 'U431612712', 'name': 'RESIDENTIAL PROPERTY'},
#  {'id': 'U572001150', 'name': 'VACANT BUILDING'},
#  {'id': 'U051512678',
#   'name': 'FD MANCELONA MICHIGAN NORTH WILLIAMS STREET LLC'},
#  {'id': 'U511809904', 'name': 'CORE ENERGY, MANISTEE B4-14'},
#  {'id': 'U511413759', 'name': 'PERCIPITATOR BLDG'},
#  {'id': 'U831412838', 'name': "HART'S RV AND REFRIDGERATION SERVICES"},
#  {'id': 'U831603869', 'name': 'MAMFID'},
#  {'id': 'U671808343', 'name': 'MARION HOTEL'},
#  {'id': 'U672103664', 'name': "REITA'S RESTAUANT"},
#  {'id': 'U672002499', 'name': 'SUBJECT BUILDING'},
#  {'id': 'U101910511', 'name': 'BAY AREA DEMOLITION, LLC'},
#  {'id': 'U282004195', 'name': 'FORMER LA SENORITA'},
#  {'id': 'U282000969', 'name': 'COMMERICAL BUILDING'},
#  {'id': 'U281602147', 'name': 'SHERWIN WILLIAMS'},
#  {'id': 'U281809232', 'name': 'ORCHARD LAKE MACHINING'},
#  {'id': 'U041704783', 'name': 'ALPENA HIGH SCHOOL'},
#  {'id': 'U042000041', 'name': 'FORMER HABITAT FOR HUMANITY'},
#  {'id': 'U151411701', 'name': 'ACAT GLOBAL'},
#  {'id': 'U151411702', 'name': 'OLIVER RACING PARTS'},
#  {'id': 'U161802897', 'name': 'COMMERCIAL'},
#  {'id': 'U161412036', 'name': 'STRAITS FEDERAL CREDIT UNION'},
#  {'id': 'U172100053', 'name': 'FOUNTAIN TRUCKING INC'},
#  {'id': 'U692104766', 'name': 'COMMERICAL BUILDING'},
#  {'id': 'U691611504', 'name': 'VACANT COMMERICAL PROPERTY'},
#  {'id': 'U691808175', 'name': 'ENERVEST OPERATING LLC - NMAG3 BOOSTER'},
#  {'id': 'U202001267', 'name': 'FORMER KMART'},
#  {'id': 'U241604911', 'name': 'TOWNSHIP RENTAL HOUSE'},
#  {'id': 'U691905711', 'name': 'RESIDENCE'},
#  {'id': 'U691709500', 'name': 'RIVERSIDE ENERGY CHARLTON 16 CPF'},
#  {'id': 'U172102874', 'name': 'PARADISE RECREATIONAL SPORTS'},
#  {'id': 'U521803398', 'name': 'WAGON WHEEL MOTEL AND CABINS'},
#  {'id': 'U171601167', 'name': 'FEDERAL PLAZA'},
#  {'id': 'U171700828', 'name': 'ADVANCE AUTO PARTS'},
#  {'id': 'U171700829', 'name': 'AUTOZONE'},
#  {'id': 'U171700830', 'name': 'WALMART'},
#  {'id': 'U172100225', 'name': 'MCM MARINE INC'},
#  {'id': 'U171603122', 'name': 'NORTHERN TRANSITIONS, INC.'},
#  {'id': 'U221410464', 'name': 'AMERICAN GRAPHICS ROTOPRINTING, INC.'},
#  {'id': 'U221701234', 'name': 'TRACTOR SUPPLY COMPANY'},
#  {'id': 'U221701235', 'name': 'WALMART'},
#  {'id': 'U221701361', 'name': 'WATER DEPARTMENT CITY OF IRON MOUNTAIN'},
#  {'id': 'U221701233', 'name': 'APC STORES'},
#  {'id': 'U551906466', 'name': 'PERFORMANCE CORPORATION'},
#  {'id': 'U552000027', 'name': 'SUPERIOR WELDING AND MANUFACTURING INC.'},
#  {'id': 'U521608711', 'name': 'RESIDENTAL HOME'},
#  {'id': 'U771601642', 'name': 'STEPHEN HARTMAN EXCAVATING INC'},
#  {'id': 'U521602075', 'name': 'CODE ELECTRICAL, INC.'},
#  {'id': 'U522001839', 'name': 'ENRIGHT CONSTRUCTION COMPANY'},
#  {'id': 'U522100181', 'name': 'UP HEALTH SYSTEM - MARQUETTE'},
#  {'id': 'U522003421', 'name': 'UP KUBOTA'},
#  {'id': 'U021800702', 'name': 'COX BUILDING'},
#  {'id': 'U021704791', 'name': 'RENZE POWER SPORTS'},
#  {'id': 'U521903390', 'name': 'NEGAUNEE PUBLIC SCHOOLS BUS GARAGE'},
#  {'id': 'U481704188', 'name': 'MUSKALLONGE LAKE STATE PARK GARAGE'},
#  {'id': 'U482004132',
#   'name': 'NORTH REGION (NEWBERRY CORR FACILITY) BLDG 1 - HOS'},
#  {'id': 'U482004291',
#   'name': 'NORTH REGION (NEWBERRY CORR FACILITY) BLDG 14 AMUS'},
#  {'id': 'U482100455',
#   'name': 'NORTH REGION (NEWBERRY CORR FACILITY) BLDG 3 COTTA'},
#  {'id': 'U482004292',
#   'name': 'NORTH REGION (NEWBERRY CORR FACILITY) BLDG 43 STOR'},
#  {'id': 'U482004285',
#   'name': 'NORTH REGION (NEWBERRY CORR FACILITY) BLDG 5 COTTA'},
#  {'id': 'U482003378',
#   'name': 'NORTH REGION (NEWBERRY CORRECTIONAL FACILITY) BLDG'},
#  {'id': 'U211705615', 'name': "ROB'S IGA"},
#  {'id': 'U171701601', 'name': 'APC STORES'},
#  {'id': 'U422100057', 'name': 'NEUVOKAS CORPORATION'},
#  {'id': 'U071512196', 'name': 'BARAGA TELEPHONE COMPANY'},
#  {'id': 'U421902331', 'name': 'OCUGLASS'},
#  {'id': 'U361604642', 'name': 'FORMER RESIDENTIAL HOME'},
#  {'id': 'U361604647', 'name': 'FORMER RESIDENTIAL HOME'},
#  {'id': 'U271703367', 'name': 'ASPIRUS GRANDVIEW CLINIC'},
#  {'id': 'U271700832', 'name': "O'REILLY AUTO ENTERPRISES LLC"},
#  {'id': 'U271700831', 'name': 'WALMART'},
#  {'id': 'U071601074', 'name': 'M.A. ENERGY RESOURCES, LLC'},
#  {'id': 'U071606687', 'name': "VILLAGE OF L'ANSE"},
#  {'id': 'U661612621', 'name': 'NORTHWOODS ENVIRONMENTAL INDUSTRIES INC'},
#  {'id': 'U661803401', 'name': 'WHITE PINE MOBIL MART'},
#  {'id': 'U831506751', 'name': 'GALLAGHER ASPHALT CORPORATION'}]

# %%
# Get the rest of the company names
# Some null values were giving me trouble, 
# so I converted null values to a string so I could filter them out more easily
import numpy as np
df1 = df.replace(np.nan, 'NaN')

company_names2 = []
for index, row in df1.iterrows():
    data = {}
    # Doing this in chunks because I knew I already captured the company names of the first 82 records
    if index < 83:
        data['id'] = row['source_id']
        data['name'] = "NaN"
    elif index >= 83:
        data['id'] = row['source_id']
        data['name'] = row['Address']
    # Filtering out NaN results and results where the name = 'Company'
    if data['name'] != 'NaN' and data['name'] != 'Company':
        company_names2.append(data)
# Got all my records
len(company_names2 + company_names1)
# Out:
# 5837

# %%
# Turning the two lists of dictionaries into dataframes so I can concatenate them.
company_names1 = pd.DataFrame(company_names1)
company_names2 = pd.DataFrame(company_names2)
frames = [company_names1, company_names2]
company_names_combined = pd.concat(frames, keys=["id", "company_name"], ignore_index=True)
company_names_combined
# Out:
#              id                                              name
# 0         N8277             TUSCOLA ENERGY INC - RUMBLE SHARP CTB
# 1         N8274  TUSCOLA ENERGY INC-BOYCE JR TRUSTEE 1&STREETER 1
# 2     U04060035                                           UNKNOWN
# 3         N7824                        RIVERSIDE - FOREST HOME 12
# 4     U15060046                                           UNKNOWN
# ...         ...                                               ...
# 5832      B1966                     WHITE PINE ELECTRIC POWER LLC
# 5833      P1069                            ALTA EQUIPMENT COMPANY
# 5834      P0067                                     LAURIE HAMMAR
# 5835      N1973                              ABHE & SOVBODA, INC.
# 5836  U82060106             WAYNE COUNTY GENERAL COMPLAINT SOURCE
#
# [5837 rows x 2 columns]

# %%
# First merging the address and name dataframes on the ID column and saving to a new dataframe
df_clean = company_names_combined.merge(address_combined, left_on="id",right_on ="id")
# The merging the city dataframe on the new dataframe and saving it again
df_clean = df_clean.merge(cities_combined, left_on="id", right_on="id")
df_clean
# Out:
#              id                                              name  \
# 0         N8277             TUSCOLA ENERGY INC - RUMBLE SHARP CTB
# 1         N8274  TUSCOLA ENERGY INC-BOYCE JR TRUSTEE 1&STREETER 1
# 2     U04060035                                           UNKNOWN
# 3         N7824                        RIVERSIDE - FOREST HOME 12
# 4     U15060046                                           UNKNOWN
# ...         ...                                               ...
# 5832      B1966                     WHITE PINE ELECTRIC POWER LLC
# 5833      P1069                            ALTA EQUIPMENT COMPANY
# 5834      P0067                                     LAURIE HAMMAR
# 5835      N1973                              ABHE & SOVBODA, INC.
# 5836  U82060106             WAYNE COUNTY GENERAL COMPLAINT SOURCE
#
#                             address         city
# 0          SE SW SW SEC 19 T14N R8E        AKRON
# 1          SW SW SW SEC 24 T14N R7E        AKRON
# 2                     ALPENA COUNTY       ALPENA
# 3     SW 1/4 NE 1/4 SEC 12 T30N R8W     BELLAIRE
# 4                 CHARLEVOIX COUNTY   CHARLEVOIX
# ...                             ...          ...
# 5832              29639 WILLOW ROAD   WHITE PINE
# 5833              1035 CALCITE ROAD  ROGERS CITY
# 5834       15524 NORTH ROCK 38TH RD         ROCK
# 5835    BLUE WATER BRIDGE & GRATIOT   PORT HURON
# 5836                            NaN          NaN
#
# [5837 rows x 4 columns]

# %%
# ------------- 5. FULL ADDRESS -------------
# I want to get a full address column so that I can get a list of addresses
# To run through the Google geocode API
full_addresses = []
for index, row in df_clean.iterrows():
    # Adding Michigan to the end for clarity
    address = f"{row['address']}, {row['city']}, MI"
    full_addresses.append(address)
full_addresses
# Saving it to a new column
df_clean['full_address'] = full_addresses
df_clean
# Out:
#              id                                              name  \
# 0         N8277             TUSCOLA ENERGY INC - RUMBLE SHARP CTB
# 1         N8274  TUSCOLA ENERGY INC-BOYCE JR TRUSTEE 1&STREETER 1
# 2     U04060035                                           UNKNOWN
# 3         N7824                        RIVERSIDE - FOREST HOME 12
# 4     U15060046                                           UNKNOWN
# ...         ...                                               ...
# 5832      B1966                     WHITE PINE ELECTRIC POWER LLC
# 5833      P1069                            ALTA EQUIPMENT COMPANY
# 5834      P0067                                     LAURIE HAMMAR
# 5835      N1973                              ABHE & SOVBODA, INC.
# 5836  U82060106             WAYNE COUNTY GENERAL COMPLAINT SOURCE
#
#                             address         city  \
# 0          SE SW SW SEC 19 T14N R8E        AKRON
# 1          SW SW SW SEC 24 T14N R7E        AKRON
# 2                     ALPENA COUNTY       ALPENA
# 3     SW 1/4 NE 1/4 SEC 12 T30N R8W     BELLAIRE
# 4                 CHARLEVOIX COUNTY   CHARLEVOIX
# ...                             ...          ...
# 5832              29639 WILLOW ROAD   WHITE PINE
# 5833              1035 CALCITE ROAD  ROGERS CITY
# 5834       15524 NORTH ROCK 38TH RD         ROCK
# 5835    BLUE WATER BRIDGE & GRATIOT   PORT HURON
# 5836                            NaN          NaN
#
#                                      full_address
# 0             SE SW SW SEC 19 T14N R8E, AKRON, MI
# 1             SW SW SW SEC 24 T14N R7E, AKRON, MI
# 2                       ALPENA COUNTY, ALPENA, MI
# 3     SW 1/4 NE 1/4 SEC 12 T30N R8W, BELLAIRE, MI
# 4               CHARLEVOIX COUNTY, CHARLEVOIX, MI
# ...                                           ...
# 5832            29639 WILLOW ROAD, WHITE PINE, MI
# 5833           1035 CALCITE ROAD, ROGERS CITY, MI
# 5834           15524 NORTH ROCK 38TH RD, ROCK, MI
# 5835  BLUE WATER BRIDGE & GRATIOT, PORT HURON, MI
# 5836                                 nan, nan, MI
#
# [5837 rows x 5 columns]

# %%
# I thought I could get county from Google API but it didn't work very well, so I'm 
# Going back to the original dataframe to get counties. Filtering out all repeated header rows.
# Should have done that at the beginning!!
df = df[df['source_id'] != 'Source']

# %%
# ------------- 6. COUNTY: CLEAN ------------- 
# Removing the zip codes from some of the County records
df['County'] = df['Unnamed: 4'].str.replace(r"^\w\w?\d+\n","")
# Removing the NA string before some of the county records
df['County'] = df['County'].str.replace(r"NA\n","")

# %%
# Looks like some of the county's have only zip codes in them
# Replacing the zip code with NaN
df['County'] = df['County'].str.replace(r"\d+","NaN")
# There are lots of NaNs and No Numbers, hurray!
df.County.value_counts()

# %%
# Filtering the dataframe for only Counties that aren't NaN
county_nozip = df[df.County != 'NaN']
county_nozip

# %%
# Pulling out the source ID and County so I can concat this df and a new df that has the rest of the counties
county_nozip_clean = county_nozip[['source_id', 'County']].copy()
county_nozip_clean = county_nozip_clean.rename(columns={'County':'county'})
county_nozip_clean
# Out:
#        source_id        county
# 0          N8277       TUSCOLA
# 1          N8274       TUSCOLA
# 2      U04060035        ALPENA
# 3          N7824        ANTRIM
# 4      U15060046    CHARLEVOIX
# ...          ...           ...
# 5972       P1069  PRESQUE ISLE
# 5973       P0067         DELTA
# 5974       N1973   SAINT CLAIR
# 5975  U831506751       WEXFORD
# 5976   U82060106         WAYNE
#
# [4841 rows x 2 columns]

# %%
# Filtering the dataframe to only have NaN County records 
county_zips = df[df.County == 'NaN']
# Making a new column that looks to the 5th Column for county names
county_zips['County2'] = county_zips['Unnamed: 5']
# Checking to see if I got any zip codes or NaNs
county_zips.County2.value_counts()

# %%
# Pulling out the source ID and County so I can concat the two dfs
county_zips_clean = county_zips[['source_id', 'County2']].copy()
county_zips_clean = county_zips_clean.rename(columns={'County2':'county'})

# %%
# Putting all the records together and I have the magic number of 5837 records
counties_clean = pd.concat([county_zips_clean, county_nozip_clean])
counties_clean
# Out:
#        source_id        county
# 1020  U631501703       OAKLAND
# 1021       N8144       OAKLAND
# 1022       N2803       OAKLAND
# 1023  U631611951       OAKLAND
# 1024       N7564       OAKLAND
# ...          ...           ...
# 5972       P1069  PRESQUE ISLE
# 5973       P0067         DELTA
# 5974       N1973   SAINT CLAIR
# 5975  U831506751       WEXFORD
# 5976   U82060106         WAYNE
#
# [5837 rows x 2 columns]

# %%
counties_clean.to_csv("counties_clean.csv", index=False)

# %%
# 7. ------------- ZIP CODES: CLEAN -------------
# Google API didn't give me reliable zip_codes so I'm going 
df['zips'] = df['Unnamed: 4'].str.split("\n").str[0]
df

# %%
# Getting the zip codes and the source_ids so I can merge on source_id
# Pulling them out in two sections for the same reasons as above
# Get the first 82 rows zip codes
zips1 = []
for index, row in df.iterrows():
    data = {}
    if index < 83:
        data['id'] = row['source_id']
        data['zip_code'] = row['ZIP Code County']
        zips1.append(data)

# Get the rest of the zip codes
zips2 = []
for index, row in df.iterrows():
    data = {}
    if index >= 83:
        data['id'] = row['source_id']
        data['zip_code'] = row['zips']
        if data['id'] != 'Source':
            zips2.append(data)
# Checking number of records
total = (len(zips1) + len(zips2))
total
# Out:
# 5837

# %%
# Turning the two lists of dictionaries into dataframes so I can concatenate them.
zips1 = pd.DataFrame(zips1)
zips2 = pd.DataFrame(zips2)
frames = [zips1, zips2]
zip_codes = pd.concat(frames, keys=["id", "zip_code"], ignore_index=True)
zip_codes['zip_code'] = zip_codes.zip_code.str.replace("NA", "NaN")
zip_codes
# Out:
#               id zip_code
# 0          N8277      NaN
# 1          N8274      NaN
# 2      U04060035      NaN
# 3          N7824      NaN
# 4      U15060046      NaN
# ...          ...      ...
# 5832       P1069    49977
# 5833       P0067    49980
# 5834       N1973    55372
# 5835  U831506751    60476
# 5836   U82060106      NaN
#
# [5837 rows x 2 columns]

# %%
# First merging the zip_codes and name dataframes on the ID column and saving to a new dataframe
df_clean = df_clean.merge(zip_codes, left_on="id",right_on ="id")
# The merging the city dataframe on the new dataframe and saving it again
df_clean = df_clean.merge(counties_clean, left_on="id", right_on="id")
df_clean
# Out:
#              id                                              name  \
# 0         N8277             TUSCOLA ENERGY INC - RUMBLE SHARP CTB
# 1         N8274  TUSCOLA ENERGY INC-BOYCE JR TRUSTEE 1&STREETER 1
# 2     U04060035                                           UNKNOWN
# 3         N7824                        RIVERSIDE - FOREST HOME 12
# 4     U15060046                                           UNKNOWN
# ...         ...                                               ...
# 5832      B1966                     WHITE PINE ELECTRIC POWER LLC
# 5833      P1069                            ALTA EQUIPMENT COMPANY
# 5834      P0067                                     LAURIE HAMMAR
# 5835      N1973                              ABHE & SOVBODA, INC.
# 5836  U82060106             WAYNE COUNTY GENERAL COMPLAINT SOURCE
#
#                             address         city zip_code        county
# 0          SE SW SW SEC 19 T14N R8E        AKRON      NaN       TUSCOLA
# 1          SW SW SW SEC 24 T14N R7E        AKRON      NaN       TUSCOLA
# 2                     ALPENA COUNTY       ALPENA      NaN        ALPENA
# 3     SW 1/4 NE 1/4 SEC 12 T30N R8W     BELLAIRE      NaN        ANTRIM
# 4                 CHARLEVOIX COUNTY   CHARLEVOIX      NaN    CHARLEVOIX
# ...                             ...          ...      ...           ...
# 5832              29639 WILLOW ROAD   WHITE PINE    49971     ONTONAGON
# 5833              1035 CALCITE ROAD  ROGERS CITY    49977  PRESQUE ISLE
# 5834       15524 NORTH ROCK 38TH RD         ROCK    49980         DELTA
# 5835    BLUE WATER BRIDGE & GRATIOT   PORT HURON    55372   SAINT CLAIR
# 5836                            NaN          NaN      NaN         WAYNE
#
# [5837 rows x 6 columns]

# %%
df_clean.to_csv("MI-source-list-cleaned.csv", index=False)

# %%
# NOTE: Along the way I manually filled in some zip codes that were not in the document
